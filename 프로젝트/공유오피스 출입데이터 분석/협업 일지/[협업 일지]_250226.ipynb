# %% [markdown]
# ### 협업일지
# #### 일자 : 2025-02-26 / 박하진

# %% [markdown]
# #### 오늘 할 일
# -
# -
# -

# %% [markdown]
# #### 오늘 한 일
# - stay_time으로 클러스터링 분석
# - firts_enter_time으로 클러스터링 분석

# %% [markdown]
# #### 내일 할 일
# -
# -
# -

# %% [markdown]
# #### Codes

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Issues & Challenges
# -
# -
# -

# %% [markdown]
# #### Reflection
# - stay_time 컬럼을 활용하여 체류시간을 3개의 구간으로 나눠 클러스터 분석을 진행하였습니다.
# - firts_enter_time 컬럼을 활용하여 출입시간을 4개의 구간으로 나눠 클러스터 분석을 진행하였습니다.
# - 둘 다 데이터가 문자형으로 되어있어 변환하고 원하는 시간으로 추출하는 과정이 있었습니다.
#
# - 아직 first_enter_time의 결측치처리가 제대로 된 것이 아니기 때문에 코드만 구현해놓고, 데이터가 보완이 되면 그 때 데이터를 바꿀 예정입니다.
