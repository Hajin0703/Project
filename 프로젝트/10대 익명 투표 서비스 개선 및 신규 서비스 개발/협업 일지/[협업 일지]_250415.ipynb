# %% [markdown]
# ### 협업일지
# #### 일자 : 2025-04- / 박하진

# %% [markdown]
# #### 오늘 할 일
# - 데이터 탐색하기
# -
# -

# %% [markdown]
# #### 오늘 한 일
# - 데이터 탐색 후 인사이트 도출 및 팀원과 공유
# -

# %% [markdown]
# #### 내일 할 일
# - 다른 테이블 데이터 탐색 후 팀원과 공유하기
# -
# -

# %% [markdown]
# #### Codes

# %% [markdown]
# #### Issues & Challenges
# -
# -
# -

# %% [markdown]
# #### Reflection
# - 아직 팀 내부에서 주제를 정한 건 아니었기에 정해두고 탐색하기보단 가능한 모든 데이터를 보려고 하고있다.
# - 먼저 가장 기본이 되는 user 정보 데이터를 탐색했다. 유저 테이블에서 가입 시기에 관련해 시각화를 했는데 가입 시기가 너무 한정적이고 가입시기 시각화 자료만 보았을 때, 앱의 문제점이 존재하는 것 같아 팀원과 바로 공유 후 회의를 진행했다. 우선 이슈의 인지 정도만 하는걸로 결론을 냈고, 마저 데이터를 둘러보기로 했다.
# - 또한 가입시기가 왜 저렇게 나왔을지에 대한 가설을 몇 개 세워 확인해봤지만, 유의미한 결과는 얻을 수 없었다.

# %% [markdown]
# ![image.png](attachment:image.png)
