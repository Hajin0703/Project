# %% [markdown]
# ### 협업일지
# #### 일자 : 2025-04-23 / 박하진

# %% [markdown]
# #### 오늘 할 일
# - 2단계 이탈 징후 분석과 3단계 지능 참여도 분석 진행 예정
# -
# -

# %% [markdown]
# #### 오늘 한 일
# -
# -

# %% [markdown]
# #### 내일 할 일
# -
# -
# -

# %% [markdown]
# #### Codes

# %% [markdown]
# #### Issues & Challenges
# -
# -
# -

# %% [markdown]
# #### Reflection
#
# 이탈 징후 분석
#
# | 지표                 | 설명                 |
# | ------------------ | ------------------ |
# | 가입 후 첫 활동까지 걸린 시간  | 가입 경험에 문제가 있었는지 확인 |
# | 가입 후 활동 지속 일수      | 얼마나 오래 활동했는지       |
# | 가입 후 3일 이내 활동 유무   | 초기 이탈자 비율 파악       |
# | 단 1회 활동 후 이탈한 유저 수 | 진입 후 바로 떠난 유저 파악   |
#
# 결과 표
#
# | 지표                      | 결과                 | 해석                                                                |
# | ----------------------- | ------------------ | ----------------------------------------------------------------- |
# | 가입 후 첫 활동까지 평균 시간   | 0.63일 (약 15시간) | 대부분의 유저가 **가입 후 하루 이내에 첫 활동**을 하고 있어. → **온보딩 경험은 크게 문제 없어 보임.**  |
# | 가입 후 평균 활동 지속일수   | 28.29일        | 꽤 긴 편이야. 평균적으로 한 달 정도는 활동한 사용자들이 많다는 뜻이야.                         |
# | 가입 후 3일 이내 활동 유저 비율 | 0.09 (9%)      | **단 9%만이 첫 3일 안에 활동을 마무리**한다는 뜻. 대부분의 유저는 3일 넘게 활동을 지속해.          |
# | 단 1회 활동 후 이탈한 유저 비율 | 0.03 (3%)     | **단 한 번 활동하고 이탈하는 유저는 적다**는 뜻. 즉, 유저들이 서비스에 진입은 잘하고 일정 시간은 머무는 편. |
#
# 인사이트 요약
# 가입 후 바로 이탈하거나 활동을 안 하는 문제가 주요 원인은 아니다.
#
# 대부분의 유저는 온보딩에 성공하고 일정 기간은 활동한다.
#
# 그런데 왜 DAU/MAU는 낮을까?
#
# → 이 말은 결국 유저들이 "지속적으로 자주" 돌아오지 않는다는 것이 핵심 문제

# %% [markdown]
# 기능별 이용 패턴 분석
#
# 지속성이 낮은 유저들이 어떤 기능을 잘 안 쓰거나, 어떤 행동을 자주 했는지를 파악해서
# 서비스 지속성 저하의 행동적 요인을 분석
#
# ### 인사이트 요약
#
# ### 1. **응답 받은 사용자가 거의 없음**
#
# > 응답 받은 사용자 수: 461명
# >
# >
# > 응답 못 받은 사용자 수: **4388명**
# >
# - **대부분의 사용자가 질문에 대한 응답을 한 번도 못 받은 상황.**
# - `answered_count`, `response_rate`가 0인 사용자 비율이 90%이상
# - → 사용자 입장에서 보면, 아무리 질문을 올려도 **"피드백이 없음"**
#
#     → 이는 **서비스 지속성 하락의 치명적 원인**
#
#
# ### 2. **기능별 행동 패턴의 양극화**
#
# | 사용자 유형 | 읽기만 함 (read_only_count 평균) | 신고 | 응답 |
# | --- | --- | --- | --- |
# | 단발성 사용자 | 3.9 | 0.0066 | 0.1 |
# | 간헐적 사용자 | 20.5 | 0.003 | 0.1 |
# | 지속 사용자 | **127.4** | **0.0487** | 0.09 |
# - 대부분의 사용자는 **보기만 하고 아무 행동도 하지 않음**
# - **응답은 아예 없고**, 일부 사용자는 **신고**만 진행
# - 지속 사용자조차도 참여 없이 **일방적인 열람 + 신고** 행동만 반복
#
# ### 3. **서비스 구조상 비대칭성**
#
# - **질문만 올라오고 응답은 없음** → 사용자 입장에서 허탈 + 피로
# - **일방향 콘텐츠 소비 구조** → 사용자 간 상호작용이 거의 없음
# - 일부 사용자가 **신고에만 치중** → 부정적 경험 증가 가능성
#
# ![image.png](attachment:image.png)
# ex) 사용자 별 신고 수 top 10
#
# ## 결론: 지속성 저하의 핵심 요인
#
# > 응답을 받지 못하는 구조적인 문제 + 일방적 열람과 신고 중심의 사용 패턴
