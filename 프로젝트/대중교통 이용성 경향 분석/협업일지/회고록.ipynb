# %% [markdown]
# ### 회고록
# #### 일자 : 2024-12-02 / 박하진

# %% [markdown]
# #### Reflection
# - 다른 조 발표에서 지표 설정할 때 검증과정을 많이 거친 것을 봤지만 우린 그러지 못해서 굉장히 아쉬움이 남았다.
# - 그래도 서로가 하고 있는 일을 바로바로 공유하는 것이 효율적인 일 방식인것을 느낄 수 있었다.
# - 주제를 정하는데 있어서 큰 틀에 대한 의사결정은 쉽게 이뤄졌지만, 세부적인 의사결정은 방향이 정해지지않아서 어려움을 겪었다.
# - 수요지수 기준으로 자치구와 대여소를 설정했고, 상위권 데이터를 주로 보느라 전체적인 데이터를 보지못해 아쉬웠다.
